# %% [markdown]
# ## Python Basics
#
# *   **Variables and Data Types**: Python has several data types, including integers, floats, strings, and booleans.
# *   **Data Structures**: List, Tuple, Set, and Dictionary are the built-in data structures in Python.
# *   **Control Flow**: Python uses if-elif-else statements for conditional execution and while-for loops for repeated execution.
# *   **Functions**: Python uses the `def` keyword to define a function.

# %% [markdown]
# ## 1\. Variables and Data Types
#
# **Variables** are containers for storing data values. In Python, a variable is created the moment you first assign a value to it.
#
# **Data Types** in Python includes:
#
# *   **Integers**: You can use an integer represent numeric data, and more specifically, whole numbers from negative infinity to infinity,like 4, 5, or -1.
# *   **Floats**: "Float" stands for 'floating point number'. You can use it for rational numbers, usually ending with a decimal figure, such as 1.11 or 3.14.
# *   **Strings**: Strings in python are surrounded by either single quotation marks, or double quotation marks.
# *   **Booleans**: Data type with one of the two built-in values, True or False. Boolean objects that are equal to True are truthy (true), and those equal to False are falsy (false).

# %% [markdown]
# *   **Floats**: "Float" stands for 'floating point number'. You can use it for rational numbers, usually ending with a decimal figure, such as 1.11 or 3.14.

# %%
# Integer Variable
x = 10
print(type(x))  # <class 'int'>

# Float Variable
y = 10.5
print(type(y))  # <class 'float'>

# String Variable
z = "Hello World!"
print(type(z))  # <class 'str'>

# Boolean Variable
a = True
print(type(a))  # <class 'bool'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Data Structures
#
# Python has several built-in data structures, such as:
#
# *   **Lists**: A list is a collection which is ordered and changeable. Allows duplicate members.
#
#
# *   **Tuples**: A tuple is a collection which is ordered and unchangeable. Allows duplicate members.
#
#
# *   **Sets**: A set is a collection which is unordered and unindexed. No duplicate members.
#
#
# *   **Dictionaries**: A dictionary is a collection which is unordered, changeable and indexed. No duplicate members.

# %%
# List
list1 = [1, 2, 3, 4, 5]
print(type(list1))  # <class 'list'>

# Tuple
tuple1 = (1, 2, 3, 4, 5)
print(type(tuple1))  # <class 'tuple'>

# Set
set1 = {1, 2, 3, 4, 5}
print(type(set1))  # <class 'set'>

# Dictionary
dict1 = {'name': 'John', 'age': 26}
print(type(dict1))  # <class 'dict'>
# Out:
# <class 'list'>

# %% [markdown]
# ## Control Flow
#
# *   **If-Elif-Else**: Python supports the usual logical conditions from mathematics. These conditions can be used in several ways, most commonly in "if statements" and loops.
# *   **While-For Loops**: A "while" loop will continue to execute as long as the condition in the loop remains true. A "for loop" is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).

# %%
a = 33
b = 200

if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")
else:
    print("a is greater than b")
# Out:
# b is greater than a

# %%
# While Loop
i = 1
while i < 6:
    print(i)
    i += 1

# For Loop
    fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# apple
# banana
# cherry

# %% [markdown]
# Control flow tools in Python also include:
#
# * **Range** function: Range in Python is a built-in function that can be used in for loops. It generates a sequence of numbers starting from 0 (by default), and increments by 1 (by default), and stops before a specified number.
# * **Break** statement: The break statement in Python terminates the current loop and resumes execution at the next statement.
# * **Continue** statement: The continue statement in Python returns the control to the beginning of the current loop. When encountered, the loop starts next iteration without executing the remaining statements in the current iteration.

# %%
for i in range(5):  # generates sequence [0, 1, 2, 3, 4]
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i == 3:
        break
    print(i)  # prints 0 1 2

print("-" * 50)

for i in range(5):
    if i == 3:
        continue
    print(i)  # prints 0 1 2 4
# Out:
# 0
# 1
# 2
# --------------------------------------------------
# 0
# 1
# 2
# 4

# %% [markdown]
# ## Functions
#
# A function is a block of code which only runs when it is called. You can pass data, known as parameters, into a function. A function can return data as a result.

# %%
# Defining a Function
def my_function():
  print("Hello from a function")

# Calling a Function
my_function()
# Out:
# Hello from a function

# %% [markdown]
# Functions in Python can have positional arguments, keyword arguments, or a mix of both.

# %%
def greet(name, greeting="Hello"):
    print(f"{greeting}, {name}")

greet("John")  # prints "Hello, John"
greet("John", greeting="Good morning")  # prints "Good morning, John"

greet(greeting="Good morning", "John")
# Out:
#   File "<ipython-input-1-41284f7596e4>", line 7
#     greet(greeting="Good morning", "John")
#                                          ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# Functions can also return values using the `return` statement.

# %%
def add(x, y):    return (x + y, x, y)
result, x, y = add(6, 3)
print(result)  # prints 3
# Out:
# 6
